# %% [markdown]
# <a href="https://colab.research.google.com/github/gembuspol/uczenieMaszynowe/blob/main/cwiczenia3_zad1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/palles77/MachineLearning_Exercise4/main/Employee_Compensation_SF.csv')

# %%
# function returning column index in a dataframe
def column_index(df, query_cols):
    cols = df.columns.values
    sidx = np.argsort(cols)
    return sidx[np.searchsorted(cols,query_cols,sorter=sidx)]

# %%
(column_first, colum_second) = column_index(dataset, ['Total Salary', 'Retirement'])
# get sample 1000 rows
dataset_for_clustering = dataset.sample(1000).iloc[:, [column_first, colum_second]].values

# %%
# Drawing dendrogram
dendrogramWard = sch.dendrogram(sch.linkage(dataset_for_clustering, method='ward'))

# %%
dendrogramComplete = sch.dendrogram(sch.linkage(dataset_for_clustering, method='complete'))

# %%
dendrogramAverange = sch.dendrogram(sch.linkage(dataset_for_clustering, method='average'))

# %%
dendrogramSingle = sch.dendrogram(sch.linkage(dataset_for_clustering, method='single'))

# %%
model = AgglomerativeClustering(n_clusters = 3, affinity='euclidean', linkage='ward')
X=dataset_for_clustering
model.fit(X)
labels = model.labels_

# %%
# Drawing Clusters
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Salary')
plt.ylabel('Retirement')
plt.show()

# %%
modelComplete = AgglomerativeClustering(n_clusters = 3, affinity='euclidean', linkage='complete')
X=dataset_for_clustering
modelComplete.fit(X)
labels = modelComplete.labels_

# %%
# Drawing Clusters Complete
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Salary')
plt.ylabel('Retirement')
plt.show()

# %%
modelAverage = AgglomerativeClustering(n_clusters = 3, affinity='euclidean', linkage='average')
X=dataset_for_clustering
modelAverage.fit(X)
labels = modelAverage.labels_

# %%
# Drawing Clusters Complete
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Salary')
plt.ylabel('Retirement')
plt.show()

# %%
modelSingle = AgglomerativeClustering(n_clusters = 3, affinity='euclidean', linkage='single')
X=dataset_for_clustering
modelSingle.fit(X)
labels = modelSingle.labels_

# %%
# Drawing Clusters Complete
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Salary')
plt.ylabel('Retirement')
plt.show()
