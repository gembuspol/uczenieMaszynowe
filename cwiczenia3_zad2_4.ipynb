# %% [markdown]
# <a href="https://colab.research.google.com/github/gembuspol/uczenieMaszynowe/blob/main/cwiczenia3_zad2_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/palles77/MachineLearning_Exercise4/main/Employee_Compensation_SF.csv')

# %%
# function returning column index in a dataframe
def column_index(df, query_cols):
    cols = df.columns.values
    sidx = np.argsort(cols)
    return sidx[np.searchsorted(cols,query_cols,sorter=sidx)]

# %%
(column_first, colum_second) = column_index(dataset, ['Total Benefits', 'Retirement'])
# get sample 1000 rows
dataset_for_clustering = dataset.sample(1000).iloc[:, [column_first, colum_second]].values

# %%
# Drawing dendrogram
dendrogramWard = sch.dendrogram(sch.linkage(dataset_for_clustering, method='ward'))

# %%
dendrogramComplete = sch.dendrogram(sch.linkage(dataset_for_clustering, method='complete'))

# %%
dendrogramAverange = sch.dendrogram(sch.linkage(dataset_for_clustering, method='average'))

# %%
dendrogramSingle = sch.dendrogram(sch.linkage(dataset_for_clustering, method='single'))

# %%
model = AgglomerativeClustering(n_clusters = 3, affinity='euclidean', linkage='complete')
X=dataset_for_clustering
model.fit(X)
labels = model.labels_

# %%
# Drawing Clusters
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Benefits')
plt.ylabel('Total Compensation')
plt.show()

# %%
modell1 = AgglomerativeClustering(n_clusters = 3, affinity='l1', linkage='complete')
X=dataset_for_clustering
modell1.fit(X)
labels = modell1.labels_

# %%
# Drawing Clusters Complete
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Benefits')
plt.ylabel('Total Compensation')
plt.show()

# %%
modell2 = AgglomerativeClustering(n_clusters = 3, affinity='l2', linkage='complete')
X=dataset_for_clustering
modell2.fit(X)
labels = modell2.labels_

# %%
# Drawing Clusters Complete
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Benefits')
plt.ylabel('Total Compensation')
plt.show()

# %%
modelManhattan = AgglomerativeClustering(n_clusters = 3, affinity='manhattan', linkage='complete')
X=dataset_for_clustering
modelManhattan.fit(X)
labels = modelManhattan.labels_

# %%
# Drawing Clusters Complete
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Benefits')
plt.ylabel('Total Compensation')
plt.show()

# %%
modelCosine = AgglomerativeClustering(n_clusters = 3, affinity='cosine', linkage='complete')
X=dataset_for_clustering
modelCosine.fit(X)
labels = modelCosine.labels_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-c0d3a4538cd9> in <module>
#       1 modelCosine = AgglomerativeClustering(n_clusters = 3, affinity='cosine', linkage='complete')
#       2 X=dataset_for_clustering
# ----> 3 modelCosine.fit(X)
#       4 labels = modelCosine.labels_
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_agglomerative.py in fit(self, X, y)
#     916         """
#     917         X = self._validate_data(X, ensure_min_samples=2, estimator=self)
# --> 918         return self._fit(X)
#     919
#     920     def _fit(self, X):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_agglomerative.py in _fit(self, X)
#    1004             n_clusters=n_clusters,
#    1005             return_distance=return_distance,
# -> 1006             **kwargs,
#    1007         )
# ...

# %%
# Drawing Clusters Complete
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Benefits')
plt.ylabel('Total Compensation')
plt.show()

# %%
modelPrecomputed = AgglomerativeClustering(n_clusters = 3, affinity='precomputed', linkage='complete')
X=dataset_for_clustering
modelPrecomputed.fit(X)
labels = modelPrecomputed.labels_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-0e7751144f7d> in <module>
#       1 modelPrecomputed = AgglomerativeClustering(n_clusters = 3, affinity='precomputed', linkage='complete')
#       2 X=dataset_for_clustering
# ----> 3 modelPrecomputed.fit(X)
#       4 labels = modelPrecomputed.labels_
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_agglomerative.py in fit(self, X, y)
#     916         """
#     917         X = self._validate_data(X, ensure_min_samples=2, estimator=self)
# --> 918         return self._fit(X)
#     919
#     920     def _fit(self, X):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_agglomerative.py in _fit(self, X)
#    1004             n_clusters=n_clusters,
#    1005             return_distance=return_distance,
# -> 1006             **kwargs,
#    1007         )
# ...

# %%
# Drawing Clusters Complete
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Benefits')
plt.ylabel('Total Compensation')
plt.show()
